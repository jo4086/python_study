# %%
# 23. tuple(): 값을 튜플로 반환
# print(tuple())

# %%
# 25. type(): 객체의 타입 반환
print(type(123))
print(type('123'))
# Out:
# <class 'int'>
# <class 'str'>

# %%
# 26. zip(): 여러 iterable한 요소를 묶어 튜플로 반환
print( list(zip([1,2], ['a', 'b'])))
# Out:
# [(1, 'a'), (2, 'b')]
