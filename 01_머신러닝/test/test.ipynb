# %%
# import shutil

# path = 'c:/project/python/study/01_머신러닝/'
csvfile = 'california_housing_train.csv'

# move_path = f'{path}{csvfile}'

# shutil.copy(move_path, f'{path}/sample_data/{csvfile}')

# %%
import csv

with open(f'../sample_data/{csvfile}', 'r') as file:
    reader = csv.reader(file)
    data = [row for row in reader]

print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 import csv
# ----> 3 with open(f'../sample_data/{csvfile}', 'r') as file:
#       4     reader = csv.reader(file)
#       5     data = [row for row in reader]
#
# NameError: name 'csvfile' is not defined
