# %%
# import 모음
import pandas as pd
import shutil
import numpy as np
import matplotlib.pyplot as plt # 파이썬에서 데이터 시각화를 위해 사용하는 기본 라이브러리
import seaborn as sns # 그래프의 디자인을 다듬어주는 라이브러리

# %% [markdown]
# # 1. 판다스 Series와 DataFrame

# %%
import pandas as pd

# %%
# 1. 판다스 Series

# 1차원 데이터 구조로 인덱스를 포함하는 배열 형태
series_example = pd.Series([10, 20, 30, 40], index=['A', 'B', 'C', 'D'])
print(series_example)
print('')
print(series_example['A'])
print(series_example['C'])
# Out:
# A    10
# B    20
# C    30
# D    40
# dtype: int64
#
# 10
# 30

# %%
# 2. 판다스 DataFrame

# DataFrame은 행과 열로 구성된 테이블 형태의 2차원 데이터 구조
# 여러 개의 Series가 모여서 DataFrame을 구성한다.

dataframe_example = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 40],
    'City': ['뉴욕', '로스엔젤레스', '시카고', '휴스톤']
})

display(dataframe_example)
print(dataframe_example)
print('')
print(dataframe_example['Name'])
print('')
print(dataframe_example['City'])
# Out:
#       Name  Age    City
# 0    Alice   25      뉴욕
# 1      Bob   30  로스엔젤레스
# 2  Charlie   35     시카고
# 3    David   40     휴스톤
#       Name  Age    City
# 0    Alice   25      뉴욕
# 1      Bob   30  로스엔젤레스
# 2  Charlie   35     시카고
# 3    David   40     휴스톤
#
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# Name: Name, dtype: object
#
# 0        뉴욕
# 1    로스엔젤레스
# 2       시카고
# 3       휴스톤
# Name: City, dtype: object

# %% [markdown]
# ### 2. california_housing_train 사용하기

# %%
# csv 파일을 DataFrame 형태로 읽기
train = pd.read_csv('sample_data/california_housing_train.csv')
train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                  15         5612            1283
# 1        -114.47     34.40                  19         7650            1901
# 2        -114.56     33.69                  17          720             174
# 3        -114.57     33.64                  14         1501             337
# 4        -114.57     33.57                  20         1454             326
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                  52         2217             394
# 16996    -124.27     40.69                  36         2349             528
# 16997    -124.30     41.84                  17         2677             531
# 16998    -124.30     41.80                  19         2672             552
# 16999    -124.35     40.54                  52         1820             300
#
#        population  households  median_income  median_house_value
# 0            1015         472         1.4936               66900
# 1            1129         463         1.8200               80100
# 2             333         117         1.6509               85700
# 3             515         226         3.1917               73400
# 4             624         262         1.9250               65500
# ...           ...         ...            ...                 ...
# 16995         907         369         2.3571              111400
# 16996        1194         465         2.5179               79000
# 16997        1244         456         3.0313              103600
# 16998        1298         478         1.9797               85800
# 16999         806         270         3.0147               94600
#
# [17000 rows x 9 columns]

# %%
# 특정 열 가져오기
train['housing_median_age']
# Out:
# 0        15
# 1        19
# 2        17
# 3        14
# 4        20
#          ..
# 16995    52
# 16996    36
# 16997    17
# 16998    19
# 16999    52
# Name: housing_median_age, Length: 17000, dtype: int64

# %%
train['population']
# Out:
# 0        1015
# 1        1129
# 2         333
# 3         515
# 4         624
#          ...
# 16995     907
# 16996    1194
# 16997    1244
# 16998    1298
# 16999     806
# Name: population, Length: 17000, dtype: int64

# %%
# 조건에 따른 필터링
# housing_median_age가 10미만 데이터만 가져오기
train_min_10 = train[train['housing_median_age'] < 10]
train_min_10
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 58       -115.52     32.67                   6         2804             581
# 75       -115.55     32.78                   5         2652             606
# 95       -115.58     32.81                   5          805             143
# 98       -115.58     32.78                   5         2494             414
# 100      -115.59     32.79                   8         2183             307
# ...          ...       ...                 ...          ...             ...
# 16679    -122.79     38.48                   7         6837            1417
# 16680    -122.79     38.42                   9         4967             885
# 16692    -122.82     38.55                   8         6190            1088
# 16776    -123.00     38.33                   8         3223             637
# 16854    -123.49     38.70                   9         5409            1019
#
#        population  households  median_income  median_house_value
# 58           2807         594         2.0625               67700
# 75           1767         536         2.8025               84300
# 95            458         143         4.4750               96300
# 98           1416         421         5.7843              110100
# 100          1000         287         6.3814              159900
# ...           ...         ...            ...                 ...
# 16679        3468        1405         3.1662              191000
# 16680        2581         915         5.0380              185600
# 16692        2967        1000         3.8616              195100
# 16776         851         418         5.6445              364800
# 16854         594         327         3.3125              295400
#
# [1087 rows x 9 columns]

# %% [markdown]
# ### 3. 데이터 프레임을 활용해서 housing_median_age가 10 미만인 데이터 삭제

# %%
train = pd.read_csv('sample_data/california_housing_train.csv')

new_data = [] # housing_median_age가 10미만인 데이터를 삭제한 결과 저장

# iterrows(): 데이터프레임의 각 행을 반복해서 행별 데이터를 가져옴
# index: 행의 인덱스
# row: 행의 데이터를 판다스 Series 형태로 반환

for index, row in train.iterrows():
    # print(index, row)
    if row.housing_median_age >= 10: # housing_median_age가 10이상인 데이터만
        new_data.append(row)

new_data
# Out:
# [longitude              -114.3100
#  latitude                 34.1900
#  housing_median_age       15.0000
#  total_rooms            5612.0000
#  total_bedrooms         1283.0000
#  population             1015.0000
#  households              472.0000
#  median_income             1.4936
#  median_house_value    66900.0000
#  Name: 0, dtype: float64,
#  longitude              -114.47
#  latitude                 34.40
#  housing_median_age       19.00
#  total_rooms            7650.00
#  total_bedrooms         1901.00
#  population             1129.00
#  households              463.00
#  median_income             1.82
#  median_house_value    80100.00
#  Name: 1, dtype: float64,
#  longitude              -114.5600
#  latitude                 33.6900
#  housing_median_age       17.0000
#  total_rooms             720.0000
#  total_bedrooms          174.0000
#  population              333.0000
#  households              117.0000
#  median_income             1.6509
#  median_house_value    85700.0000
#  Name: 2, dtype: float64,
#  longitude              -114.5700
#  latitude                 33.6400
#  housing_median_age       14.0000
#  total_rooms            1501.0000
#  total_bedrooms          337.0000
#  population              515.0000
#  households              226.0000
#  median_income             3.1917
#  median_house_value    73400.0000
#  Name: 3, dtype: float64,
#  longitude              -114.570
#  latitude                 33.570
#  housing_median_age       20.000
#  total_rooms            1454.000
#  total_bedrooms          326.000
#  population              624.000
#  households              262.000
#  median_income             1.925
#  median_house_value    65500.000
#  Name: 4, dtype: float64,
#  longitude              -114.5800
#  latitude                 33.6300
#  housing_median_age       29.0000
#  total_rooms            1387.0000
#  total_bedrooms          236.0000
#  population              671.0000
#  households              239.0000
#  median_income             3.3438
#  median_house_value    74000.0000
#  Name: 5, dtype: float64,
#  longitude              -114.5800
#  latitude                 33.6100
#  housing_median_age       25.0000
#  total_rooms            2907.0000
#  total_bedrooms          680.0000
#  population             1841.0000
#  households              633.0000
#  median_income             2.6768
#  median_house_value    82400.0000
#  Name: 6, dtype: float64,
#  longitude              -114.5900
#  latitude                 34.8300
#  housing_median_age       41.0000
#  total_rooms             812.0000
#  total_bedrooms          168.0000
#  population              375.0000
#  households              158.0000
#  median_income             1.7083
#  median_house_value    48500.0000
#  Name: 7, dtype: float64,
#  longitude              -114.5900
#  latitude                 33.6100
#  housing_median_age       34.0000
#  total_rooms            4789.0000
#  total_bedrooms         1175.0000
#  population             3134.0000
#  households             1056.0000
#  median_income             2.1782
#  median_house_value    58400.0000
#  Name: 8, dtype: float64,
#  longitude              -114.6000
#  latitude                 34.8300
#  housing_median_age       46.0000
#  total_rooms            1497.0000
#  total_bedrooms          309.0000
#  population              787.0000
#  households              271.0000
#  median_income             2.1908
#  median_house_value    48100.0000
#  Name: 9, dtype: float64,
#  longitude              -114.6000
#  latitude                 33.6200
#  housing_median_age       16.0000
#  total_rooms            3741.0000
#  total_bedrooms          801.0000
#  population             2434.0000
#  households              824.0000
#  median_income             2.6797
#  median_house_value    86500.0000
#  Name: 10, dtype: float64,
#  longitude              -114.600
#  latitude                 33.600
#  housing_median_age       21.000
#  total_rooms            1988.000
#  total_bedrooms          483.000
#  population             1182.000
#  households              437.000
#  median_income             1.625
#  median_house_value    62000.000
#  Name: 11, dtype: float64,
#  longitude              -114.6100
#  latitude                 34.8400
#  housing_median_age       48.0000
#  total_rooms            1291.0000
#  total_bedrooms          248.0000
#  population              580.0000
#  households              211.0000
#  median_income             2.1571
#  median_house_value    48600.0000
#  Name: 12, dtype: float64,
#  longitude              -114.610
#  latitude                 34.830
#  housing_median_age       31.000
#  total_rooms            2478.000
#  total_bedrooms          464.000
#  population             1346.000
#  households              479.000
#  median_income             3.212
#  median_house_value    70400.000
#  Name: 13, dtype: float64,
#  longitude              -114.6300
#  latitude                 32.7600
#  housing_median_age       15.0000
#  total_rooms            1448.0000
#  total_bedrooms          378.0000
#  population              949.0000
#  households              300.0000
#  median_income             0.8585
#  median_house_value    45000.0000
#  Name: 14, dtype: float64,
#  longitude              -114.6500
#  latitude                 34.8900
#  housing_median_age       17.0000
#  total_rooms            2556.0000
#  total_bedrooms          587.0000
#  population             1005.0000
#  households              401.0000
#  median_income             1.6991
#  median_house_value    69100.0000
#  Name: 15, dtype: float64,
#  longitude              -114.6500
#  latitude                 33.6000
#  housing_median_age       28.0000
#  total_rooms            1678.0000
#  total_bedrooms          322.0000
#  population              666.0000
#  households              256.0000
#  median_income             2.9653
#  median_house_value    94900.0000
#  Name: 16, dtype: float64,
#  longitude              -114.6500
#  latitude                 32.7900
#  housing_median_age       21.0000
#  total_rooms              44.0000
#  total_bedrooms           33.0000
#  population               64.0000
#  households               27.0000
#  median_income             0.8571
#  median_house_value    25000.0000
#  Name: 17, dtype: float64,
#  longitude              -114.6600
#  latitude                 32.7400
#  housing_median_age       17.0000
#  total_rooms            1388.0000
#  total_bedrooms          386.0000
#  population              775.0000
#  households              320.0000
#  median_income             1.2049
#  median_house_value    44000.0000
#  Name: 18, dtype: float64,
#  longitude              -114.6700
#  latitude                 33.9200
#  housing_median_age       17.0000
#  total_rooms              97.0000
#  total_bedrooms           24.0000
#  population               29.0000
#  households               15.0000
#  median_income             1.2656
#  median_house_value    27500.0000
#  Name: 19, dtype: float64,
#  longitude              -114.6800
#  latitude                 33.4900
#  housing_median_age       20.0000
#  total_rooms            1491.0000
#  total_bedrooms          360.0000
#  population             1135.0000
#  households              303.0000
#  median_income             1.6395
#  median_house_value    44400.0000
#  Name: 20, dtype: float64,
#  longitude              -114.7300
#  latitude                 33.4300
#  housing_median_age       24.0000
#  total_rooms             796.0000
#  total_bedrooms          243.0000
#  population              227.0000
#  households              139.0000
#  median_income             0.8964
#  median_house_value    59200.0000
#  Name: 21, dtype: float64,
#  longitude              -114.940
#  latitude                 34.550
#  housing_median_age       20.000
#  total_rooms             350.000
#  total_bedrooms           95.000
#  population              119.000
#  households               58.000
#  median_income             1.625
#  median_house_value    50000.000
#  Name: 22, dtype: float64,
#  longitude              -114.9800
#  latitude                 33.8200
#  housing_median_age       15.0000
#  total_rooms             644.0000
#  total_bedrooms          129.0000
#  population              137.0000
#  households               52.0000
#  median_income             3.2097
#  median_house_value    71300.0000
#  Name: 23, dtype: float64,
#  longitude              -115.220
#  latitude                 33.540
#  housing_median_age       18.000
#  total_rooms            1706.000
#  total_bedrooms          397.000
#  population             3424.000
#  households              283.000
#  median_income             1.625
#  median_house_value    53500.000
#  Name: 24, dtype: float64,
#  longitude               -115.3200
#  latitude                  32.8200
#  housing_median_age        34.0000
#  total_rooms              591.0000
#  total_bedrooms           139.0000
#  population               327.0000
#  households                89.0000
#  median_income              3.6528
#  median_house_value    100000.0000
#  Name: 25, dtype: float64,
#  longitude              -115.3700
#  latitude                 32.8200
#  housing_median_age       30.0000
#  total_rooms            1602.0000
#  total_bedrooms          322.0000
#  population             1130.0000
#  households              335.0000
#  median_income             3.5735
#  median_house_value    71100.0000
#  Name: 26, dtype: float64,
#  longitude              -115.3700
#  latitude                 32.8200
#  housing_median_age       14.0000
#  total_rooms            1276.0000
#  total_bedrooms          270.0000
#  population              867.0000
#  households              261.0000
#  median_income             1.9375
#  median_house_value    80900.0000
#  Name: 27, dtype: float64,
#  longitude              -115.3700
#  latitude                 32.8100
#  housing_median_age       32.0000
#  total_rooms             741.0000
#  total_bedrooms          191.0000
#  population              623.0000
#  households              169.0000
#  median_income             1.7604
#  median_house_value    68600.0000
#  Name: 28, dtype: float64,
#  longitude              -115.3700
#  latitude                 32.8100
#  housing_median_age       23.0000
#  total_rooms            1458.0000
#  total_bedrooms          294.0000
#  population              866.0000
#  households              275.0000
#  median_income             2.3594
#  median_house_value    74300.0000
#  Name: 29, dtype: float64,
#  longitude              -115.3800
#  latitude                 32.8200
#  housing_median_age       38.0000
#  total_rooms            1892.0000
#  total_bedrooms          394.0000
#  population             1175.0000
#  households              374.0000
#  median_income             1.9939
#  median_house_value    65800.0000
#  Name: 30, dtype: float64,
#  longitude              -115.3800
#  latitude                 32.8100
#  housing_median_age       35.0000
#  total_rooms            1263.0000
#  total_bedrooms          262.0000
#  population              950.0000
#  households              241.0000
#  median_income             1.8958
#  median_house_value    67500.0000
#  Name: 31, dtype: float64,
#  longitude               -115.3900
#  latitude                  32.7600
#  housing_median_age        16.0000
#  total_rooms             1136.0000
#  total_bedrooms           196.0000
#  population               481.0000
#  households               185.0000
#  median_income              6.2558
#  median_house_value    146300.0000
#  Name: 32, dtype: float64,
#  longitude               -115.4000
#  latitude                  32.8600
#  housing_median_age        19.0000
#  total_rooms             1087.0000
#  total_bedrooms           171.0000
#  population               649.0000
#  households               173.0000
#  median_income              3.3182
#  median_house_value    113800.0000
#  Name: 33, dtype: float64,
#  longitude              -115.4000
#  latitude                 32.7000
#  housing_median_age       19.0000
#  total_rooms             583.0000
#  total_bedrooms          113.0000
#  population              531.0000
#  households              134.0000
#  median_income             1.6838
#  median_house_value    95800.0000
#  Name: 34, dtype: float64,
#  longitude               -115.4100
#  latitude                  32.9900
#  housing_median_age        29.0000
#  total_rooms             1141.0000
#  total_bedrooms           220.0000
#  population               684.0000
#  households               194.0000
#  median_income              3.4038
#  median_house_value    107800.0000
#  Name: 35, dtype: float64,
#  longitude              -115.46
#  latitude                 33.19
#  housing_median_age       33.00
#  total_rooms            1234.00
#  total_bedrooms          373.00
#  population              777.00
#  households              298.00
#  median_income             1.00
#  median_house_value    40000.00
#  Name: 36, dtype: float64,
#  longitude              -115.4800
#  latitude                 32.8000
#  housing_median_age       21.0000
#  total_rooms            1260.0000
#  total_bedrooms          246.0000
#  population              805.0000
#  households              239.0000
#  median_income             2.6172
#  median_house_value    88500.0000
#  Name: 37, dtype: float64,
#  longitude              -115.4800
#  latitude                 32.6800
#  housing_median_age       15.0000
#  total_rooms            3414.0000
#  total_bedrooms          666.0000
#  population             2097.0000
#  households              622.0000
#  median_income             2.3319
#  median_house_value    91200.0000
#  Name: 38, dtype: float64,
#  longitude               -115.4900
#  latitude                  32.8700
#  housing_median_age        19.0000
#  total_rooms              541.0000
#  total_bedrooms           104.0000
#  population               457.0000
#  households               106.0000
#  median_income              3.3583
#  median_house_value    102800.0000
#  Name: 39, dtype: float64,
#  longitude              -115.490
#  latitude                 32.690
#  housing_median_age       17.000
#  total_rooms            1960.000
#  total_bedrooms          389.000
#  population             1691.000
#  households              356.000
#  median_income             1.899
#  median_house_value    64000.000
#  Name: 40, dtype: float64,
#  longitude              -115.4900
#  latitude                 32.6700
#  housing_median_age       29.0000
#  total_rooms            1523.0000
#  total_bedrooms          440.0000
#  population             1302.0000
#  households              393.0000
#  median_income             1.1311
#  median_house_value    84700.0000
#  Name: 41, dtype: float64,
#  longitude              -115.490
#  latitude                 32.670
#  housing_median_age       25.000
#  total_rooms            2322.000
#  total_bedrooms          573.000
#  population             2185.000
#  households              602.000
#  median_income             1.375
#  median_house_value    70100.000
#  Name: 42, dtype: float64,
#  longitude               -115.5000
#  latitude                  32.7500
#  housing_median_age        13.0000
#  total_rooms              330.0000
#  total_bedrooms            72.0000
#  population               822.0000
#  households                64.0000
#  median_income              3.4107
#  median_house_value    142500.0000
#  Name: 43, dtype: float64,
#  longitude              -115.5000
#  latitude                 32.6800
#  housing_median_age       18.0000
#  total_rooms            3631.0000
#  total_bedrooms          913.0000
#  population             3565.0000
#  households              924.0000
#  median_income             1.5931
#  median_house_value    88400.0000
#  Name: 44, dtype: float64,
#  longitude              -115.5000
#  latitude                 32.6700
#  housing_median_age       35.0000
#  total_rooms            2159.0000
#  total_bedrooms          492.0000
#  population             1694.0000
#  households              475.0000
#  median_income             2.1776
#  median_house_value    75500.0000
#  Name: 45, dtype: float64,
#  longitude              -115.5100
#  latitude                 33.2400
#  housing_median_age       32.0000
#  total_rooms            1995.0000
#  total_bedrooms          523.0000
#  population             1069.0000
#  households              410.0000
#  median_income             1.6552
#  median_house_value    43300.0000
#  Name: 46, dtype: float64,
#  longitude              -115.510
#  latitude                 33.120
#  housing_median_age       21.000
#  total_rooms            1024.000
#  total_bedrooms          218.000
#  population              890.000
#  households              232.000
#  median_income             2.101
#  median_house_value    46700.000
#  Name: 47, dtype: float64,
#  longitude              -115.5100
#  latitude                 32.9900
#  housing_median_age       20.0000
#  total_rooms            1402.0000
#  total_bedrooms          287.0000
#  population             1104.0000
#  households              317.0000
#  median_income             1.9088
#  median_house_value    63700.0000
#  Name: 48, dtype: float64,
#  longitude              -115.510
#  latitude                 32.680
#  housing_median_age       11.000
#  total_rooms            2872.000
#  total_bedrooms          610.000
#  population             2644.000
#  households              581.000
#  median_income             2.625
#  median_house_value    72700.000
#  Name: 49, dtype: float64,
#  longitude              -115.5200
#  latitude                 34.2200
#  housing_median_age       30.0000
#  total_rooms             540.0000
#  total_bedrooms          136.0000
#  population              122.0000
#  households               63.0000
#  median_income             1.3333
#  median_house_value    42500.0000
#  Name: 50, dtype: float64,
#  longitude              -115.520
#  latitude                 33.130
#  housing_median_age       18.000
#  total_rooms            1109.000
#  total_bedrooms          283.000
#  population             1006.000
#  households              253.000
#  median_income             2.163
#  median_house_value    53400.000
#  Name: 51, dtype: float64,
#  longitude              -115.5200
#  latitude                 33.1200
#  housing_median_age       38.0000
#  total_rooms            1327.0000
#  total_bedrooms          262.0000
#  population              784.0000
#  households              231.0000
#  median_income             1.8793
#  median_house_value    60800.0000
#  Name: 52, dtype: float64,
#  longitude              -115.5200
#  latitude                 32.9800
#  housing_median_age       32.0000
#  total_rooms            1615.0000
#  total_bedrooms          382.0000
#  population             1307.0000
#  households              345.0000
#  median_income             1.4583
#  median_house_value    58600.0000
#  Name: 53, dtype: float64,
#  longitude              -115.520
#  latitude                 32.970
#  housing_median_age       24.000
#  total_rooms            1617.000
#  total_bedrooms          366.000
#  population             1416.000
#  households              401.000
#  median_income             1.975
#  median_house_value    66400.000
#  Name: 54, dtype: float64,
#  longitude              -115.5200
#  latitude                 32.9700
#  housing_median_age       10.0000
#  total_rooms            1879.0000
#  total_bedrooms          387.0000
#  population             1376.0000
#  households              337.0000
#  median_income             1.9911
#  median_house_value    67500.0000
#  Name: 55, dtype: float64,
#  longitude              -115.5200
#  latitude                 32.7700
#  housing_median_age       18.0000
#  total_rooms            1715.0000
#  total_bedrooms          337.0000
#  population             1166.0000
#  households              333.0000
#  median_income             2.2417
#  median_house_value    79200.0000
#  Name: 56, dtype: float64,
#  longitude              -115.5200
#  latitude                 32.7300
#  housing_median_age       17.0000
#  total_rooms            1190.0000
#  total_bedrooms          275.0000
#  population             1113.0000
#  households              258.0000
#  median_income             2.3571
#  median_house_value    63100.0000
#  Name: 57, dtype: float64,
#  longitude              -115.5300
#  latitude                 34.9100
#  housing_median_age       12.0000
#  total_rooms             807.0000
#  total_bedrooms          199.0000
#  population              246.0000
#  households              102.0000
#  median_income             2.5391
#  median_house_value    40000.0000
#  Name: 59, dtype: float64,
#  longitude              -115.5300
#  latitude                 32.9900
#  housing_median_age       25.0000
#  total_rooms            2578.0000
#  total_bedrooms          634.0000
#  population             2082.0000
#  households              565.0000
#  median_income             1.7159
#  median_house_value    62200.0000
#  Name: 60, dtype: float64,
#  longitude              -115.5300
#  latitude                 32.9700
#  housing_median_age       35.0000
#  total_rooms            1583.0000
#  total_bedrooms          340.0000
#  population              933.0000
#  households              318.0000
#  median_income             2.4063
#  median_house_value    70700.0000
#  Name: 61, dtype: float64,
#  longitude              -115.5300
#  latitude                 32.9700
#  housing_median_age       34.0000
#  total_rooms            2231.0000
#  total_bedrooms          545.0000
#  population             1568.0000
#  households              510.0000
#  median_income             1.5217
#  median_house_value    60300.0000
#  Name: 62, dtype: float64,
#  longitude              -115.530
#  latitude                 32.730
#  housing_median_age       14.000
#  total_rooms            1527.000
#  total_bedrooms          325.000
#  population             1453.000
#  households              332.000
#  median_income             1.735
#  median_house_value    61200.000
#  Name: 63, dtype: float64,
#  longitude              -115.5400
#  latitude                 32.9900
#  housing_median_age       23.0000
#  total_rooms            1459.0000
#  total_bedrooms          373.0000
#  population             1148.0000
#  households              388.0000
#  median_income             1.5372
#  median_house_value    69400.0000
#  Name: 64, dtype: float64,
#  longitude              -115.5400
#  latitude                 32.9900
#  housing_median_age       17.0000
#  total_rooms            1697.0000
#  total_bedrooms          268.0000
#  population              911.0000
#  households              254.0000
#  median_income             4.3523
#  median_house_value    96000.0000
#  Name: 65, dtype: float64,
#  longitude              -115.5400
#  latitude                 32.9800
#  housing_median_age       27.0000
#  total_rooms            1513.0000
#  total_bedrooms          395.0000
#  population             1121.0000
#  households              381.0000
#  median_income             1.9464
#  median_house_value    60600.0000
#  Name: 66, dtype: float64,
#  longitude              -115.5400
#  latitude                 32.9700
#  housing_median_age       41.0000
#  total_rooms            2429.0000
#  total_bedrooms          454.0000
#  population             1188.0000
#  households              430.0000
#  median_income             3.0091
#  median_house_value    70800.0000
#  Name: 67, dtype: float64,
#  longitude              -115.540
#  latitude                 32.790
#  housing_median_age       23.000
#  total_rooms            1712.000
#  total_bedrooms          403.000
#  population             1370.000
#  households              377.000
#  median_income             1.275
#  median_house_value    60400.000
#  Name: 68, dtype: float64,
#  longitude               -115.5500
#  latitude                  32.9800
#  housing_median_age        33.0000
#  total_rooms             2266.0000
#  total_bedrooms           365.0000
#  population               952.0000
#  households               360.0000
#  median_income              5.4349
#  median_house_value    143000.0000
#  Name: 69, dtype: float64,
#  longitude              -115.5500
#  latitude                 32.9800
#  housing_median_age       24.0000
#  total_rooms            2565.0000
#  total_bedrooms          530.0000
#  population             1447.0000
#  households              473.0000
#  median_income             3.2593
#  median_house_value    80800.0000
#  Name: 70, dtype: float64,
#  longitude              -115.5500
#  latitude                 32.8200
#  housing_median_age       34.0000
#  total_rooms            1540.0000
#  total_bedrooms          316.0000
#  population             1013.0000
#  households              274.0000
#  median_income             2.5664
#  median_house_value    67500.0000
#  Name: 71, dtype: float64,
#  longitude              -115.5500
#  latitude                 32.8000
#  housing_median_age       23.0000
#  total_rooms             666.0000
#  total_bedrooms          142.0000
#  population              580.0000
#  households              160.0000
#  median_income             2.1136
#  median_house_value    61000.0000
#  Name: 72, dtype: float64,
#  longitude              -115.5500
#  latitude                 32.7900
#  housing_median_age       23.0000
#  total_rooms            1004.0000
#  total_bedrooms          221.0000
#  population              697.0000
#  households              201.0000
#  median_income             1.6351
#  median_house_value    59600.0000
#  Name: 73, dtype: float64,
#  longitude              -115.5500
#  latitude                 32.7900
#  housing_median_age       22.0000
#  total_rooms             565.0000
#  total_bedrooms          162.0000
#  population              692.0000
#  households              141.0000
#  median_income             1.2083
#  median_house_value    53600.0000
#  Name: 74, dtype: float64,
#  longitude               -115.5600
#  latitude                  32.9600
#  housing_median_age        21.0000
#  total_rooms             2164.0000
#  total_bedrooms           480.0000
#  population              1164.0000
#  households               421.0000
#  median_income              3.8177
#  median_house_value    107200.0000
#  Name: 76, dtype: float64,
#  longitude              -115.5600
#  latitude                 32.8000
#  housing_median_age       28.0000
#  total_rooms            1672.0000
#  total_bedrooms          416.0000
#  population             1335.0000
#  households              397.0000
#  median_income             1.5987
#  median_house_value    59400.0000
#  Name: 77, dtype: float64,
#  longitude              -115.5600
#  latitude                 32.8000
#  housing_median_age       25.0000
#  total_rooms            1311.0000
#  total_bedrooms          375.0000
#  population             1193.0000
#  households              351.0000
#  median_income             2.1979
#  median_house_value    63900.0000
#  Name: 78, dtype: float64,
#  longitude              -115.5600
#  latitude                 32.8000
#  housing_median_age       15.0000
#  total_rooms            1171.0000
#  total_bedrooms          328.0000
#  population             1024.0000
#  households              298.0000
#  median_income             1.3882
#  median_house_value    69400.0000
#  Name: 79, dtype: float64,
#  longitude              -115.5600
#  latitude                 32.7900
#  housing_median_age       20.0000
#  total_rooms            2372.0000
#  total_bedrooms          835.0000
#  population             2283.0000
#  households              767.0000
#  median_income             1.1707
#  median_house_value    62500.0000
#  Name: 80, dtype: float64,
#  longitude              -115.5600
#  latitude                 32.7900
#  housing_median_age       18.0000
#  total_rooms            1178.0000
#  total_bedrooms          438.0000
#  population             1377.0000
#  households              429.0000
#  median_income             1.3373
#  median_house_value    58300.0000
#  Name: 81, dtype: float64,
#  longitude              -115.5600
#  latitude                 32.7800
#  housing_median_age       46.0000
#  total_rooms            2511.0000
#  total_bedrooms          490.0000
#  population             1583.0000
#  households              469.0000
#  median_income             3.0603
#  median_house_value    70800.0000
#  Name: 82, dtype: float64,
#  longitude              -115.5600
#  latitude                 32.7800
#  housing_median_age       35.0000
#  total_rooms            1185.0000
#  total_bedrooms          202.0000
#  population              615.0000
#  households              191.0000
#  median_income             4.6154
#  median_house_value    86200.0000
#  Name: 83, dtype: float64,
#  longitude              -115.5600
#  latitude                 32.7800
#  housing_median_age       29.0000
#  total_rooms            1568.0000
#  total_bedrooms          283.0000
#  population              848.0000
#  households              245.0000
#  median_income             3.1597
#  median_house_value    76200.0000
#  Name: 84, dtype: float64,
#  longitude               -115.5600
#  latitude                  32.7600
#  housing_median_age        15.0000
#  total_rooms             1278.0000
#  total_bedrooms           217.0000
#  population               653.0000
#  households               185.0000
#  median_income              4.4821
#  median_house_value    140300.0000
#  Name: 85, dtype: float64,
#  longitude              -115.5700
#  latitude                 32.8500
#  housing_median_age       33.0000
#  total_rooms            1365.0000
#  total_bedrooms          269.0000
#  population              825.0000
#  households              250.0000
#  median_income             3.2396
#  median_house_value    62300.0000
#  Name: 86, dtype: float64,
#  longitude              -115.5700
#  latitude                 32.8500
#  housing_median_age       17.0000
#  total_rooms            1039.0000
#  total_bedrooms          256.0000
#  population              728.0000
#  households              246.0000
#  median_income             1.7411
#  median_house_value    63500.0000
#  Name: 87, dtype: float64,
#  longitude              -115.5700
#  latitude                 32.8400
#  housing_median_age       29.0000
#  total_rooms            1207.0000
#  total_bedrooms          301.0000
#  population              804.0000
#  households              288.0000
#  median_income             1.9531
#  median_house_value    61100.0000
#  Name: 88, dtype: float64,
#  longitude              -115.5700
#  latitude                 32.8300
#  housing_median_age       31.0000
#  total_rooms            1494.0000
#  total_bedrooms          289.0000
#  population              959.0000
#  households              284.0000
#  median_income             3.5282
#  median_house_value    67500.0000
#  Name: 89, dtype: float64,
#  longitude              -115.570
#  latitude                 32.800
#  housing_median_age       16.000
#  total_rooms            2276.000
#  total_bedrooms          594.000
#  population             1184.000
#  households              513.000
#  median_income             1.875
#  median_house_value    93800.000
#  Name: 90, dtype: float64,
#  longitude              -115.5700
#  latitude                 32.7900
#  housing_median_age       34.0000
#  total_rooms            1152.0000
#  total_bedrooms          208.0000
#  population              621.0000
#  households              208.0000
#  median_income             3.6042
#  median_house_value    73600.0000
#  Name: 91, dtype: float64,
#  longitude              -115.5700
#  latitude                 32.7800
#  housing_median_age       20.0000
#  total_rooms            1534.0000
#  total_bedrooms          235.0000
#  population              871.0000
#  households              222.0000
#  median_income             6.2715
#  median_house_value    97200.0000
#  Name: 92, dtype: float64,
#  longitude              -115.5700
#  latitude                 32.7800
#  housing_median_age       15.0000
#  total_rooms            1413.0000
#  total_bedrooms          279.0000
#  population              803.0000
#  households              277.0000
#  median_income             4.3021
#  median_house_value    87500.0000
#  Name: 93, dtype: float64,
#  longitude              -115.5800
#  latitude                 33.8800
#  housing_median_age       21.0000
#  total_rooms            1161.0000
#  total_bedrooms          282.0000
#  population              724.0000
#  households              186.0000
#  median_income             3.1827
#  median_house_value    71700.0000
#  Name: 94, dtype: float64,
#  longitude              -115.5800
#  latitude                 32.8100
#  housing_median_age       10.0000
#  total_rooms            1088.0000
#  total_bedrooms          203.0000
#  population              533.0000
#  households              201.0000
#  median_income             3.6597
#  median_house_value    87500.0000
#  Name: 96, dtype: float64,
#  longitude              -115.5800
#  latitude                 32.7900
#  housing_median_age       14.0000
#  total_rooms            1687.0000
#  total_bedrooms          507.0000
#  population              762.0000
#  households              451.0000
#  median_income             1.6635
#  median_house_value    64400.0000
#  Name: 97, dtype: float64,
#  longitude              -115.590
#  latitude                 32.850
#  housing_median_age       20.000
#  total_rooms            1608.000
#  total_bedrooms          274.000
#  population              862.000
#  households              248.000
#  median_income             4.875
#  median_house_value    90800.000
#  Name: 99, dtype: float64,
#  longitude              -115.5900
#  latitude                 32.6900
#  housing_median_age       30.0000
#  total_rooms             935.0000
#  total_bedrooms          177.0000
#  population              649.0000
#  households              148.0000
#  median_income             2.5769
#  median_house_value    94400.0000
#  Name: 101, dtype: float64,
#  longitude              -115.6000
#  latitude                 33.2000
#  housing_median_age       37.0000
#  total_rooms             709.0000
#  total_bedrooms          187.0000
#  population              390.0000
#  households              142.0000
#  median_income             2.4511
#  median_house_value    72500.0000
#  Name: 102, dtype: float64,
#  longitude              -115.6200
#  latitude                 33.0400
#  housing_median_age       20.0000
#  total_rooms            1121.0000
#  total_bedrooms          244.0000
#  population              766.0000
#  households              230.0000
#  median_income             2.2969
#  median_house_value    62000.0000
#  Name: 104, dtype: float64,
#  longitude              -115.6200
#  latitude                 33.0400
#  housing_median_age       17.0000
#  total_rooms            1009.0000
#  total_bedrooms          231.0000
#  population              745.0000
#  households              217.0000
#  median_income             2.0463
#  median_house_value    61200.0000
#  Name: 105, dtype: float64,
#  longitude               -115.6400
#  latitude                  32.8000
#  housing_median_age        23.0000
#  total_rooms             1228.0000
#  total_bedrooms           235.0000
#  population               569.0000
#  households               235.0000
#  median_income              3.1667
#  median_house_value    125000.0000
#  Name: 106, dtype: float64,
#  longitude              -115.6900
#  latitude                 32.7900
#  housing_median_age       18.0000
#  total_rooms            1564.0000
#  total_bedrooms          340.0000
#  population             1161.0000
#  households              343.0000
#  median_income             2.1792
#  median_house_value    55200.0000
#  Name: 107, dtype: float64,
#  longitude              -115.7200
#  latitude                 32.7500
#  housing_median_age       16.0000
#  total_rooms             348.0000
#  total_bedrooms           99.0000
#  population              123.0000
#  households               54.0000
#  median_income             2.0938
#  median_house_value    87500.0000
#  Name: 108, dtype: float64,
#  longitude              -115.7300
#  latitude                 33.3600
#  housing_median_age       19.0000
#  total_rooms             749.0000
#  total_bedrooms          238.0000
#  population              476.0000
#  households              169.0000
#  median_income             1.7727
#  median_house_value    50000.0000
#  Name: 109, dtype: float64,
#  longitude              -115.7300
#  latitude                 33.3500
#  housing_median_age       23.0000
#  total_rooms            1586.0000
#  total_bedrooms          448.0000
#  population              338.0000
#  households              182.0000
#  median_income             1.2132
#  median_house_value    30000.0000
#  Name: 110, dtype: float64,
#  longitude              -115.73
#  latitude                 33.09
#  housing_median_age       27.00
#  total_rooms             452.00
#  total_bedrooms          103.00
#  population              258.00
#  households               61.00
#  median_income             2.90
#  median_house_value    87500.00
#  Name: 111, dtype: float64,
#  longitude              -115.7300
#  latitude                 32.8000
#  housing_median_age       44.0000
#  total_rooms             472.0000
#  total_bedrooms           81.0000
#  population              206.0000
#  households               57.0000
#  median_income             2.2083
#  median_house_value    93800.0000
#  Name: 112, dtype: float64,
#  longitude              -115.8400
#  latitude                 33.4900
#  housing_median_age       20.0000
#  total_rooms            1660.0000
#  total_bedrooms          379.0000
#  population              637.0000
#  households              250.0000
#  median_income             2.0347
#  median_house_value    68900.0000
#  Name: 114, dtype: float64,
#  longitude              -115.8500
#  latitude                 34.2000
#  housing_median_age       34.0000
#  total_rooms            3868.0000
#  total_bedrooms         1257.0000
#  population              890.0000
#  households              423.0000
#  median_income             1.3571
#  median_house_value    41000.0000
#  Name: 115, dtype: float64,
#  longitude              -115.8800
#  latitude                 32.9300
#  housing_median_age       15.0000
#  total_rooms             208.0000
#  total_bedrooms           49.0000
#  population               51.0000
#  households               20.0000
#  median_income             4.0208
#  median_house_value    32500.0000
#  Name: 116, dtype: float64,
#  longitude              -115.9000
#  latitude                 33.3400
#  housing_median_age       19.0000
#  total_rooms            1210.0000
#  total_bedrooms          248.0000
#  population              329.0000
#  households              155.0000
#  median_income             1.7857
#  median_house_value    62800.0000
#  Name: 117, dtype: float64,
#  longitude              -115.910
#  latitude                 33.360
#  housing_median_age       15.000
#  total_rooms             459.000
#  total_bedrooms           95.000
#  population              160.000
#  households               73.000
#  median_income             0.922
#  median_house_value    67500.000
#  Name: 118, dtype: float64,
#  longitude              -115.9300
#  latitude                 35.5500
#  housing_median_age       18.0000
#  total_rooms            1321.0000
#  total_bedrooms          272.0000
#  population              754.0000
#  households              226.0000
#  median_income             3.4028
#  median_house_value    67500.0000
#  Name: 119, dtype: float64,
#  longitude              -115.9500
#  latitude                 33.2800
#  housing_median_age       12.0000
#  total_rooms              99.0000
#  total_bedrooms           25.0000
#  population               37.0000
#  households               17.0000
#  median_income             1.8958
#  median_house_value    53800.0000
#  Name: 121, dtype: float64,
#  longitude              -115.960
#  latitude                 33.300
#  housing_median_age       27.000
#  total_rooms             322.000
#  total_bedrooms           81.000
#  population              112.000
#  households               57.000
#  median_income             1.125
#  median_house_value    54400.000
#  Name: 122, dtype: float64,
#  longitude              -115.9900
#  latitude                 33.4000
#  housing_median_age       15.0000
#  total_rooms            1945.0000
#  total_bedrooms          536.0000
#  population              515.0000
#  households              273.0000
#  median_income             2.0109
#  median_house_value    54300.0000
#  Name: 124, dtype: float64,
#  longitude              -116.0000
#  latitude                 33.1900
#  housing_median_age       16.0000
#  total_rooms             245.0000
#  total_bedrooms           57.0000
#  population               81.0000
#  households               33.0000
#  median_income             1.2639
#  median_house_value    51300.0000
#  Name: 125, dtype: float64,
#  longitude              -116.0000
#  latitude                 32.7400
#  housing_median_age       26.0000
#  total_rooms            1134.0000
#  total_bedrooms          280.0000
#  population              329.0000
#  households              158.0000
#  median_income             1.4338
#  median_house_value    43900.0000
#  Name: 126, dtype: float64,
#  longitude              -116.0100
#  latitude                 33.5100
#  housing_median_age       24.0000
#  total_rooms            2985.0000
#  total_bedrooms          958.0000
#  population             4042.0000
#  households              905.0000
#  median_income             1.7344
#  median_house_value    66400.0000
#  Name: 127, dtype: float64,
#  longitude              -116.0100
#  latitude                 33.4100
#  housing_median_age       20.0000
#  total_rooms            1996.0000
#  total_bedrooms          515.0000
#  population              659.0000
#  households              295.0000
#  median_income             2.8684
#  median_house_value    62800.0000
#  Name: 128, dtype: float64,
#  longitude              -116.050
#  latitude                 34.120
#  housing_median_age       19.000
#  total_rooms             301.000
#  total_bedrooms           65.000
#  population              150.000
#  households               56.000
#  median_income             3.125
#  median_house_value    65600.000
#  Name: 130, dtype: float64,
#  longitude              -116.0500
#  latitude                 33.3300
#  housing_median_age       17.0000
#  total_rooms             290.0000
#  total_bedrooms           94.0000
#  population              135.0000
#  households               57.0000
#  median_income             1.7292
#  median_house_value    81300.0000
#  Name: 131, dtype: float64,
#  longitude              -116.0600
#  latitude                 34.2000
#  housing_median_age       29.0000
#  total_rooms            1202.0000
#  total_bedrooms          290.0000
#  population              383.0000
#  households              156.0000
#  median_income             1.3371
#  median_house_value    66900.0000
#  Name: 132, dtype: float64,
#  longitude              -116.0600
#  latitude                 34.1500
#  housing_median_age       15.0000
#  total_rooms           10377.0000
#  total_bedrooms         2331.0000
#  population             4507.0000
#  households             1807.0000
#  median_income             2.2466
#  median_house_value    66800.0000
#  Name: 133, dtype: float64,
#  longitude              -116.080
#  latitude                 33.860
#  housing_median_age       16.000
#  total_rooms             381.000
#  total_bedrooms           89.000
#  population              182.000
#  households               75.000
#  median_income             2.425
#  median_house_value    76100.000
#  Name: 134, dtype: float64,
#  longitude              -116.0900
#  latitude                 34.1500
#  housing_median_age       13.0000
#  total_rooms            9444.0000
#  total_bedrooms         1997.0000
#  population             4166.0000
#  households             1482.0000
#  median_income             2.6111
#  median_house_value    65600.0000
#  Name: 135, dtype: float64,
#  longitude              -116.1100
#  latitude                 33.6400
#  housing_median_age       20.0000
#  total_rooms            1273.0000
#  total_bedrooms          354.0000
#  population             1548.0000
#  households              355.0000
#  median_income             2.0871
#  median_house_value    84700.0000
#  Name: 136, dtype: float64,
#  longitude               -116.120
#  latitude                  33.530
#  housing_median_age        17.000
#  total_rooms             2421.000
#  total_bedrooms           820.000
#  population              2971.000
#  households               685.000
#  median_income              1.654
#  median_house_value    100000.000
#  Name: 137, dtype: float64,
#  longitude              -116.140
#  latitude                 34.220
#  housing_median_age       32.000
#  total_rooms            3298.000
#  total_bedrooms         1228.000
#  population              763.000
#  households              360.000
#  median_income             1.875
#  median_house_value    47800.000
#  Name: 138, dtype: float64,
#  longitude              -116.1500
#  latitude                 34.1400
#  housing_median_age       18.0000
#  total_rooms            3312.0000
#  total_bedrooms          705.0000
#  population             1251.0000
#  households              512.0000
#  median_income             3.0139
#  median_house_value    82600.0000
#  Name: 139, dtype: float64,
#  longitude               -116.1500
#  latitude                  33.6900
#  housing_median_age        22.0000
#  total_rooms              197.0000
#  total_bedrooms            54.0000
#  population               331.0000
#  households                70.0000
#  median_income              2.9286
#  median_house_value    112500.0000
#  Name: 140, dtype: float64,
#  longitude              -116.1500
#  latitude                 33.6400
#  housing_median_age       10.0000
#  total_rooms            1711.0000
#  total_bedrooms          499.0000
#  population             1896.0000
#  households              443.0000
#  median_income             1.6557
#  median_house_value    65400.0000
#  Name: 141, dtype: float64,
#  longitude              -116.1600
#  latitude                 33.6800
#  housing_median_age       12.0000
#  total_rooms            1230.0000
#  total_bedrooms          277.0000
#  population             1334.0000
#  households              260.0000
#  median_income             2.2679
#  median_house_value    61400.0000
#  Name: 142, dtype: float64,
#  longitude              -116.1700
#  latitude                 33.6700
#  housing_median_age       18.0000
#  total_rooms            3585.0000
#  total_bedrooms          800.0000
#  population             3873.0000
#  households              788.0000
#  median_income             2.5714
#  median_house_value    65900.0000
#  Name: 143, dtype: float64,
#  longitude              -116.1700
#  latitude                 33.6600
#  housing_median_age       22.0000
#  total_rooms             639.0000
#  total_bedrooms          203.0000
#  population              664.0000
#  households              153.0000
#  median_income             1.9306
#  median_house_value    47500.0000
#  Name: 144, dtype: float64,
#  longitude              -116.1700
#  latitude                 33.5300
#  housing_median_age       13.0000
#  total_rooms            1713.0000
#  total_bedrooms          512.0000
#  population             1978.0000
#  households              442.0000
#  median_income             2.1287
#  median_house_value    58600.0000
#  Name: 145, dtype: float64,
#  longitude               -116.180
#  latitude                  33.690
#  housing_median_age        17.000
#  total_rooms               89.000
#  total_bedrooms            19.000
#  population                79.000
#  households                21.000
#  median_income              2.375
#  median_house_value    155000.000
#  Name: 146, dtype: float64,
#  longitude              -116.1800
#  latitude                 33.6700
#  housing_median_age       25.0000
#  total_rooms            2888.0000
#  total_bedrooms          654.0000
#  population             2940.0000
#  households              660.0000
#  median_income             2.2141
#  median_house_value    66700.0000
#  Name: 147, dtype: float64,
#  longitude              -116.1900
#  latitude                 33.6700
#  housing_median_age       16.0000
#  total_rooms            1859.0000
#  total_bedrooms          476.0000
#  population             1994.0000
#  households              477.0000
#  median_income             1.7297
#  median_house_value    67500.0000
#  Name: 148, dtype: float64,
#  longitude              -116.2000
#  latitude                 33.7000
#  housing_median_age       26.0000
#  total_rooms            2399.0000
#  total_bedrooms          625.0000
#  population             2654.0000
#  households              535.0000
#  median_income             2.2989
#  median_house_value    60600.0000
#  Name: 149, dtype: float64,
#  longitude              -116.20
#  latitude                 33.63
#  housing_median_age       23.00
#  total_rooms            1152.00
#  total_bedrooms          273.00
#  population             1077.00
#  households              235.00
#  median_income             2.50
#  median_house_value    96300.00
#  Name: 150, dtype: float64,
#  longitude              -116.2000
#  latitude                 32.6400
#  housing_median_age       28.0000
#  total_rooms            1608.0000
#  total_bedrooms          409.0000
#  population              567.0000
#  households              254.0000
#  median_income             1.4648
#  median_house_value    61800.0000
#  Name: 151, dtype: float64,
#  longitude              -116.2100
#  latitude                 33.7500
#  housing_median_age       22.0000
#  total_rooms             894.0000
#  total_bedrooms          192.0000
#  population              830.0000
#  households              202.0000
#  median_income             3.0673
#  median_house_value    68200.0000
#  Name: 152, dtype: float64,
#  longitude              -116.2100
#  latitude                 33.7200
#  housing_median_age       28.0000
#  total_rooms            2488.0000
#  total_bedrooms          714.0000
#  population             2891.0000
#  households              676.0000
#  median_income             2.3169
#  median_house_value    68900.0000
#  Name: 153, dtype: float64,
#  longitude              -116.2100
#  latitude                 33.7100
#  housing_median_age       19.0000
#  total_rooms            3114.0000
# ...
#  households               352.0000
#  median_income              4.4766
#  median_house_value    161500.0000
#  Name: 1064, dtype: float64,
#  longitude               -117.11
#  latitude                  32.84
#  housing_median_age        16.00
#  total_rooms             4608.00
#  total_bedrooms           629.00
#  population              2020.00
#  households               636.00
#  median_income              6.04
#  median_house_value    243000.00
#  Name: 1065, dtype: float64,
#  longitude               -117.110
#  latitude                  32.820
#  housing_median_age        16.000
#  total_rooms             4241.000
#  total_bedrooms           892.000
#  population              1771.000
#  households               864.000
#  median_income              4.375
#  median_house_value    166500.000
#  Name: 1066, dtype: float64,
#  longitude               -117.1100
#  latitude                  32.8200
#  housing_median_age        16.0000
#  total_rooms             3980.0000
#  total_bedrooms           682.0000
#  population              3174.0000
#  households               647.0000
#  median_income              2.6607
#  median_house_value    175000.0000
#  Name: 1067, dtype: float64,
#  longitude              -117.1100
#  latitude                 32.8100
#  housing_median_age       15.0000
#  total_rooms            3428.0000
#  total_bedrooms          491.0000
#  population             2303.0000
#  households              486.0000
#  median_income             2.5953
#  median_house_value    67500.0000
#  Name: 1068, dtype: float64,
#  longitude              -117.1100
#  latitude                 32.8000
#  housing_median_age       17.0000
#  total_rooms            3890.0000
#  total_bedrooms          586.0000
#  population             2791.0000
#  households              595.0000
#  median_income             3.2197
#  median_house_value    67500.0000
#  Name: 1069, dtype: float64,
#  longitude              -117.1100
#  latitude                 32.7900
#  housing_median_age       16.0000
#  total_rooms            2574.0000
#  total_bedrooms          771.0000
#  population             1129.0000
#  households              721.0000
#  median_income             3.3849
#  median_house_value    96900.0000
#  Name: 1070, dtype: float64,
#  longitude               -117.1100
#  latitude                  32.7900
#  housing_median_age        16.0000
#  total_rooms             1791.0000
#  total_bedrooms           518.0000
#  population              1006.0000
#  households               491.0000
#  median_income              3.5179
#  median_house_value    129300.0000
#  Name: 1071, dtype: float64,
#  longitude              -117.1100
#  latitude                 32.7800
#  housing_median_age       16.0000
#  total_rooms            2470.0000
#  total_bedrooms          830.0000
#  population             1170.0000
#  households              724.0000
#  median_income             3.5562
#  median_house_value    73500.0000
#  Name: 1072, dtype: float64,
#  longitude               -117.1100
#  latitude                  32.7800
#  housing_median_age        16.0000
#  total_rooms             2220.0000
#  total_bedrooms           512.0000
#  population               930.0000
#  households               527.0000
#  median_income              3.6528
#  median_house_value    133200.0000
#  Name: 1073, dtype: float64,
#  longitude               -117.1100
#  latitude                  32.7700
#  housing_median_age        52.0000
#  total_rooms             1506.0000
#  total_bedrooms           233.0000
#  population               478.0000
#  households               240.0000
#  median_income              4.3875
#  median_house_value    300000.0000
#  Name: 1074, dtype: float64,
#  longitude               -117.1100
#  latitude                  32.7700
#  housing_median_age        52.0000
#  total_rooms             1484.0000
#  total_bedrooms           224.0000
#  population               498.0000
#  households               223.0000
#  median_income              6.6053
#  median_house_value    331400.0000
#  Name: 1075, dtype: float64,
#  longitude               -117.1100
#  latitude                  32.7700
#  housing_median_age        50.0000
#  total_rooms             1729.0000
#  total_bedrooms           355.0000
#  population               617.0000
#  households               337.0000
#  median_income              3.6705
#  median_house_value    167000.0000
#  Name: 1076, dtype: float64,
#  longitude               -117.1100
#  latitude                  32.7700
#  housing_median_age        48.0000
#  total_rooms             1502.0000
#  total_bedrooms           272.0000
#  population               590.0000
#  households               265.0000
#  median_income              2.5952
#  median_house_value    190300.0000
#  Name: 1077, dtype: float64,
#  longitude               -117.1100
#  latitude                  32.7600
#  housing_median_age        29.0000
#  total_rooms             2030.0000
#  total_bedrooms           545.0000
#  population              1014.0000
#  households               518.0000
#  median_income              2.2409
#  median_house_value    114200.0000
#  Name: 1078, dtype: float64,
#  longitude               -117.1100
#  latitude                  32.7600
#  housing_median_age        28.0000
#  total_rooms             1457.0000
#  total_bedrooms           397.0000
#  population               672.0000
#  households               342.0000
#  median_income              1.9799
#  median_house_value    122700.0000
#  Name: 1079, dtype: float64,
#  longitude               -117.1100
#  latitude                  32.7600
#  housing_median_age        21.0000
#  total_rooms             2226.0000
#  total_bedrooms           600.0000
#  population              1085.0000
#  households               533.0000
#  median_income              2.2604
#  median_house_value    126300.0000
#  Name: 1080, dtype: float64,
#  longitude               -117.1100
#  latitude                  32.7600
#  housing_median_age        19.0000
#  total_rooms             2188.0000
#  total_bedrooms           616.0000
#  population              1304.0000
#  households               607.0000
#  median_income              2.0852
#  median_house_value    114400.0000
#  Name: 1081, dtype: float64,
#  longitude              -117.1100
#  latitude                 32.7500
#  housing_median_age       46.0000
#  total_rooms             695.0000
#  total_bedrooms          182.0000
#  population              601.0000
#  households              195.0000
#  median_income             2.4219
#  median_house_value    90600.0000
#  Name: 1082, dtype: float64,
#  longitude               -117.110
#  latitude                  32.750
#  housing_median_age        34.000
#  total_rooms             2131.000
#  total_bedrooms           594.000
#  population              1373.000
#  households               562.000
#  median_income              2.113
#  median_house_value    102100.000
#  Name: 1083, dtype: float64,
#  longitude               -117.1100
#  latitude                  32.7500
#  housing_median_age        21.0000
#  total_rooms             2127.0000
#  total_bedrooms           658.0000
#  population              1812.0000
#  households               603.0000
#  median_income              1.6896
#  median_house_value    100000.0000
#  Name: 1084, dtype: float64,
#  longitude               -117.1100
#  latitude                  32.7500
#  housing_median_age        20.0000
#  total_rooms             1667.0000
#  total_bedrooms           469.0000
#  population              1292.0000
#  households               445.0000
#  median_income              2.0893
#  median_house_value    101100.0000
#  Name: 1085, dtype: float64,
#  longitude               -117.11
#  latitude                  32.75
#  housing_median_age        11.00
#  total_rooms             1607.00
#  total_bedrooms           478.00
#  population              1384.00
#  households               450.00
#  median_income              2.05
#  median_house_value    100000.00
#  Name: 1086, dtype: float64,
#  longitude               -117.1100
#  latitude                  32.7400
#  housing_median_age        33.0000
#  total_rooms             1126.0000
#  total_bedrooms           267.0000
#  population               621.0000
#  households               241.0000
#  median_income              3.2422
#  median_house_value    123100.0000
#  Name: 1087, dtype: float64,
#  longitude              -117.1100
#  latitude                 32.7400
#  housing_median_age       25.0000
#  total_rooms             684.0000
#  total_bedrooms          190.0000
#  population              665.0000
#  households              187.0000
#  median_income             2.4524
#  median_house_value    90300.0000
#  Name: 1088, dtype: float64,
#  longitude              -117.11
#  latitude                 32.74
#  housing_median_age       25.00
#  total_rooms            2846.00
#  total_bedrooms          644.00
#  population             2272.00
#  households              632.00
#  median_income             2.20
#  median_house_value    98700.00
#  Name: 1089, dtype: float64,
#  longitude              -117.1100
#  latitude                 32.7300
#  housing_median_age       35.0000
#  total_rooms            1689.0000
#  total_bedrooms          397.0000
#  population             1135.0000
#  households              366.0000
#  median_income             2.3269
#  median_house_value    97300.0000
#  Name: 1090, dtype: float64,
#  longitude               -117.1100
#  latitude                  32.7300
#  housing_median_age        34.0000
#  total_rooms             1096.0000
#  total_bedrooms           221.0000
#  population               574.0000
#  households               223.0000
#  median_income              3.8355
#  median_house_value    126700.0000
#  Name: 1091, dtype: float64,
#  longitude              -117.1100
#  latitude                 32.7200
#  housing_median_age       25.0000
#  total_rooms            1491.0000
#  total_bedrooms          348.0000
#  population             1183.0000
#  households              316.0000
#  median_income             1.9583
#  median_house_value    88600.0000
#  Name: 1092, dtype: float64,
#  longitude              -117.11
#  latitude                 32.71
#  housing_median_age       30.00
#  total_rooms            1729.00
#  total_bedrooms          457.00
#  population             1673.00
#  households              460.00
#  median_income             1.70
#  median_house_value    85900.00
#  Name: 1093, dtype: float64,
#  longitude              -117.1100
#  latitude                 32.7100
#  housing_median_age       29.0000
#  total_rooms            1040.0000
#  total_bedrooms          291.0000
#  population             1054.0000
#  households              297.0000
#  median_income             1.1818
#  median_house_value    83200.0000
#  Name: 1094, dtype: float64,
#  longitude              -117.1100
#  latitude                 32.7000
#  housing_median_age       37.0000
#  total_rooms            2045.0000
#  total_bedrooms          502.0000
#  population             1920.0000
#  households              472.0000
#  median_income             1.8125
#  median_house_value    83300.0000
#  Name: 1095, dtype: float64,
#  longitude              -117.1100
#  latitude                 32.7000
#  housing_median_age       34.0000
#  total_rooms            2028.0000
#  total_bedrooms          522.0000
#  population             1797.0000
#  households              464.0000
#  median_income             1.7402
#  median_house_value    79400.0000
#  Name: 1096, dtype: float64,
#  longitude              -117.1100
#  latitude                 32.7000
#  housing_median_age       33.0000
#  total_rooms            1980.0000
#  total_bedrooms          488.0000
#  population             1626.0000
#  households              428.0000
#  median_income             1.4856
#  median_house_value    86400.0000
#  Name: 1097, dtype: float64,
#  longitude              -117.110
#  latitude                 32.690
#  housing_median_age       39.000
#  total_rooms             395.000
#  total_bedrooms          159.000
#  population              620.000
#  households              162.000
#  median_income             2.725
#  median_house_value    86500.000
#  Name: 1098, dtype: float64,
#  longitude              -117.1100
#  latitude                 32.6900
#  housing_median_age       37.0000
#  total_rooms            2395.0000
#  total_bedrooms          627.0000
#  population             2489.0000
#  households              599.0000
#  median_income             1.5933
#  median_house_value    86300.0000
#  Name: 1099, dtype: float64,
#  longitude              -117.1100
#  latitude                 32.6900
#  housing_median_age       36.0000
#  total_rooms            1421.0000
#  total_bedrooms          367.0000
#  population             1418.0000
#  households              355.0000
#  median_income             1.9425
#  median_house_value    93400.0000
#  Name: 1100, dtype: float64,
#  longitude              -117.11
#  latitude                 32.69
#  housing_median_age       34.00
#  total_rooms            1144.00
#  total_bedrooms          295.00
#  population             1271.00
#  households              302.00
#  median_income             2.09
#  median_house_value    91800.00
#  Name: 1101, dtype: float64,
#  longitude               -117.1100
#  latitude                  32.6800
#  housing_median_age        36.0000
#  total_rooms               26.0000
#  total_bedrooms            14.0000
#  population                58.0000
#  households                23.0000
#  median_income              1.9107
#  median_house_value    125000.0000
#  Name: 1102, dtype: float64,
#  longitude              -117.1100
#  latitude                 32.6700
#  housing_median_age       52.0000
#  total_rooms             280.0000
#  total_bedrooms           71.0000
#  population              217.0000
#  households               71.0000
#  median_income             1.4844
#  median_house_value    83300.0000
#  Name: 1103, dtype: float64,
#  longitude              -117.1100
#  latitude                 32.6700
#  housing_median_age       52.0000
#  total_rooms             204.0000
#  total_bedrooms           74.0000
#  population              248.0000
#  households               57.0000
#  median_income             1.7961
#  median_house_value    47500.0000
#  Name: 1104, dtype: float64,
#  longitude              -117.1100
#  latitude                 32.6700
#  housing_median_age       46.0000
#  total_rooms             928.0000
#  total_bedrooms          236.0000
#  population              790.0000
#  households              235.0000
#  median_income             1.6806
#  median_house_value    92500.0000
#  Name: 1105, dtype: float64,
#  longitude              -117.1100
#  latitude                 32.6700
#  housing_median_age       43.0000
#  total_rooms             515.0000
#  total_bedrooms          146.0000
#  population              445.0000
#  households              140.0000
#  median_income             1.6094
#  median_house_value    93000.0000
#  Name: 1106, dtype: float64,
#  longitude              -117.110
#  latitude                 32.640
#  housing_median_age       23.000
#  total_rooms            1619.000
#  total_bedrooms          447.000
#  population             1025.000
#  households              415.000
#  median_income             1.858
#  median_house_value    67500.000
#  Name: 1107, dtype: float64,
#  longitude               -117.1100
#  latitude                  32.6200
#  housing_median_age        27.0000
#  total_rooms             1846.0000
#  total_bedrooms           509.0000
#  population              1078.0000
#  households               482.0000
#  median_income              2.1719
#  median_house_value    131500.0000
#  Name: 1108, dtype: float64,
#  longitude               -117.1100
#  latitude                  32.5900
#  housing_median_age        18.0000
#  total_rooms             2329.0000
#  total_bedrooms           580.0000
#  population              1538.0000
#  households               567.0000
#  median_income              2.1179
#  median_house_value    153100.0000
#  Name: 1109, dtype: float64,
#  longitude               -117.1100
#  latitude                  32.5900
#  housing_median_age        17.0000
#  total_rooms             2020.0000
#  total_bedrooms           534.0000
#  population              1529.0000
#  households               500.0000
#  median_income              2.1773
#  median_house_value    143200.0000
#  Name: 1110, dtype: float64,
#  longitude               -117.1100
#  latitude                  32.5800
#  housing_median_age        28.0000
#  total_rooms             1869.0000
#  total_bedrooms           407.0000
#  population              1074.0000
#  households               344.0000
#  median_income              2.5988
#  median_house_value    135600.0000
#  Name: 1111, dtype: float64,
#  ...]

# %%
new_train = pd.DataFrame(new_data)
new_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 3           515.0       226.0         3.1917             73400.0
# 4           624.0       262.0         1.9250             65500.0
# ...           ...         ...            ...                 ...
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0
#
# [15913 rows x 9 columns]

# %%
train = pd.read_csv('sample_data/california_housing_train.csv')
print(train.loc[58]) # 58번째 행 데이터 조회
# Out:
# longitude              -115.5200
# latitude                 32.6700
# housing_median_age        6.0000
# total_rooms            2804.0000
# total_bedrooms          581.0000
# population             2807.0000
# households              594.0000
# median_income             2.0625
# median_house_value    67700.0000
# Name: 58, dtype: float64

# %%
# train.loc[행, 열]: 행과 열을 동시에 선택
# train.loc[58, 'housing_median_age']

# housing_median_age가 10미만인 행을 가져오는데 housing_median_age 컬럼값만 가져온다
train.loc[train['housing_median_age'] < 10, 'housing_median_age']
# Out:
# 58       6
# 75       5
# 95       5
# 98       5
# 100      8
#         ..
# 16679    7
# 16680    9
# 16692    8
# 16776    8
# 16854    9
# Name: housing_median_age, Length: 1087, dtype: int64

# %%
train.loc[train['housing_median_age'] < 10, 'housing_median_age'] * 10
# Out:
# 58       60
# 75       50
# 95       50
# 98       50
# 100      80
#          ..
# 16679    70
# 16680    90
# 16692    80
# 16776    80
# 16854    90
# Name: housing_median_age, Length: 1087, dtype: int64

# %%
# 10미만인 housing_median_age 값들에 10 곱하기
train.loc[train['housing_median_age'] < 10, 'housing_median_age'] = train.loc[train['housing_median_age'] < 10, 'housing_median_age'] * 10
print(train.loc[58]) # 58번행 값을 다시 조회
# Out:
# longitude              -115.5200
# latitude                 32.6700
# housing_median_age       60.0000
# total_rooms            2804.0000
# total_bedrooms          581.0000
# population             2807.0000
# households              594.0000
# median_income             2.0625
# median_house_value    67700.0000
# Name: 58, dtype: float64

# %% [markdown]
# ### 5. 데이터 생성

# %%
train = pd.read_csv('sample_data/california_housing_train.csv')
print(train.loc[58])
# Out:
# longitude              -115.5200
# latitude                 32.6700
# housing_median_age        6.0000
# total_rooms            2804.0000
# total_bedrooms          581.0000
# population             2807.0000
# households              594.0000
# median_income             2.0625
# median_house_value    67700.0000
# Name: 58, dtype: float64

# %%
train.loc[train['housing_median_age'] < 10, 'housing_median_age']
# Out:
# 58       6
# 75       5
# 95       5
# 98       5
# 100      8
#         ..
# 16679    7
# 16680    9
# 16692    8
# 16776    8
# 16854    9
# Name: housing_median_age, Length: 1087, dtype: int64

# %%
import numpy as np

# np.log() 자연로그 계산
np.log(60)
# Out:
# 4.0943445622221

# %%
# housing_median_age가 10미만인 housing_median_age값에 10을 곱한 후 자연로그 값을 구함

np.log(train.loc[train['housing_median_age'] < 10, 'housing_median_age'] * 10)
# Out:
# 58       4.094345
# 75       3.912023
# 95       3.912023
# 98       3.912023
# 100      4.382027
#            ...
# 16679    4.248495
# 16680    4.499810
# 16692    4.382027
# 16776    4.382027
# 16854    4.499810
# Name: housing_median_age, Length: 1087, dtype: float64

# %%
train.loc[train['housing_median_age'] < 10, 'housing_median_age_log'] = np.log(train.loc[train['housing_median_age'] < 10, 'housing_median_age'] * 10)

# %%
train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                  15         5612            1283
# 1        -114.47     34.40                  19         7650            1901
# 2        -114.56     33.69                  17          720             174
# 3        -114.57     33.64                  14         1501             337
# 4        -114.57     33.57                  20         1454             326
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                  52         2217             394
# 16996    -124.27     40.69                  36         2349             528
# 16997    -124.30     41.84                  17         2677             531
# 16998    -124.30     41.80                  19         2672             552
# 16999    -124.35     40.54                  52         1820             300
#
#        population  households  median_income  median_house_value  \
# 0            1015         472         1.4936               66900
# 1            1129         463         1.8200               80100
# 2             333         117         1.6509               85700
# 3             515         226         3.1917               73400
# 4             624         262         1.9250               65500
# ...           ...         ...            ...                 ...
# 16995         907         369         2.3571              111400
# 16996        1194         465         2.5179               79000
# 16997        1244         456         3.0313              103600
# 16998        1298         478         1.9797               85800
# 16999         806         270         3.0147               94600
#
#        housing_median_age_log
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 16995                     NaN
# 16996                     NaN
# 16997                     NaN
# 16998                     NaN
# 16999                     NaN
#
# [17000 rows x 10 columns]

# %% [markdown]
# ### 6. Pyplot을 사용한 그래프 생성

# %%
import matplotlib.pyplot as plt # 파이썬에서 데이터 시각화를 위해 사용하는 기본 라이브러리
import seaborn as sns # 그래프의 디자인을 다듬어주는 라이브러리

# %%
# train[col3].plot(kind='hist')
