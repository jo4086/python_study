# %%
# import-ipynb 라이브러리 설치 후 이용

# %%
pip install import-ipynb
# Out:
# Requirement already satisfied: import-ipynb in c:\users\rc\appdata\local\programs\python\python313\lib\site-packages (0.2)
# Requirement already satisfied: IPython in c:\users\rc\appdata\roaming\python\python313\site-packages (from import-ipynb) (8.31.0)
# Requirement already satisfied: nbformat in c:\users\rc\appdata\local\programs\python\python313\lib\site-packages (from import-ipynb) (5.10.4)
# Requirement already satisfied: colorama in c:\users\rc\appdata\roaming\python\python313\site-packages (from IPython->import-ipynb) (0.4.6)
# Requirement already satisfied: decorator in c:\users\rc\appdata\roaming\python\python313\site-packages (from IPython->import-ipynb) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\rc\appdata\roaming\python\python313\site-packages (from IPython->import-ipynb) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\rc\appdata\roaming\python\python313\site-packages (from IPython->import-ipynb) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\rc\appdata\roaming\python\python313\site-packages (from IPython->import-ipynb) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\rc\appdata\roaming\python\python313\site-packages (from IPython->import-ipynb) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\rc\appdata\roaming\python\python313\site-packages (from IPython->import-ipynb) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\rc\appdata\roaming\python\python313\site-packages (from IPython->import-ipynb) (5.14.3)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\rc\appdata\local\programs\python\python313\lib\site-packages (from nbformat->import-ipynb) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\rc\appdata\local\programs\python\python313\lib\site-packages (from nbformat->import-ipynb) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\rc\appdata\roaming\python\python313\site-packages (from nbformat->import-ipynb) (5.7.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\rc\appdata\roaming\python\python313\site-packages (from jedi>=0.16->IPython->import-ipynb) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\rc\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\rc\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\rc\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.36.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\rc\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.22.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\rc\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->import-ipynb) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\rc\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->import-ipynb) (308)
# Requirement already satisfied: wcwidth in c:\users\rc\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->IPython->import-ipynb) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\rc\appdata\roaming\python\python313\site-packages (from stack_data->IPython->import-ipynb) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\rc\appdata\roaming\python\python313\site-packages (from stack_data->IPython->import-ipynb) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\rc\appdata\roaming\python\python313\site-packages (from stack_data->IPython->import-ipynb) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import import_ipynb
import mod1

print(mod1.add(3, 5))
print(mod1.sub(4, 2))
# Out:
# 8
# 2

# %%
from mod1 import add
print(mod1.add(3, 4))
# Out:
# 7

# %%
from mod1 import add, sub
print(mod1.sub(4, 2))
# Out:
# 2

# %%
# from mod1 import *
print(mod1.add(3, 4))
print(mod1.sub(4, 2))
# Out:
# 7
# 2

# %%
import import_ipynb
import mod1

#상수 사용가능
print(mod1.PI)

#클래스 사용가능
a = mod1.Math()
print(a.solv(2))
# Out:
# 3.141592
# 12.566368

# %%
import game.sound.echo
game.sound.echo.echo_test()
# Out:
# echo

# %%
from game.sound import echo
echo.echo_test()
# Out:
# echo

# %%
from game.sound.echo import echo_test
echo_test()
# Out:
# echo

# %%
from game.sound import *
echo.echo_test()
# Out:
# echo

# %%
#__init__.py 사용하기

# import importlib  #캐시문제 발생시 실행
import game
# importlib.reload(game) #캐시문제 발생시 실행

print(game.VERSION)
game.print_version_info()
game.render_test()
# Out:
# 3.5
# The version of this game is 3.5.
# render
